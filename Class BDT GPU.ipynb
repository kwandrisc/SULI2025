# %%
import yaml
from typing import List, Dict
from sklearn.model_selection import train_test_split
import uproot
import os
import glob
import xgboost as xgb
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, roc_curve
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
class BinaryDecisionTreeSelf_df:
    def __init__(self, yaml_file: str): # identifying that the yaml file should be a string
        """
        Initialize with configurations from a YAML file.
        :param yaml_file: Path to the YAML configuration file.
        """
        # defining each of the attributes
        self.input_paths = None
        self.samples = {}
        self.variables = []
        self.hyperparameters = {}
        self.model = None
        self.dataframes = {"background": None, "signal": None}

        # calling two of the functions up here, even though only defined below
        # can do this bc reads classes all first, then goes through
        self._parse_yaml(yaml_file)
        self._load_data()

    def _parse_yaml(self, yaml_file: str):
        try: # try means that if error happens, it'll go to exception
            # use 'with' to make sure that yaml file is closed after it's opened
            with open(yaml_file, 'r' ) as file: # telling to read the file and call it "file"
                config = yaml.safe_load(file)

            # defining the attributes from things inside yaml file
            self.input_paths = config['input_path']
            self.samples[0] = config.get(0, []) # defining first column of samples as those under the key 0 in the yaml file - also, if 0 doesn't exist, return empty list "[]"
            self.samples[1] = config.get(1, []) # defining second column of samples to be things under key 1 in file
            self.variables = config.get('variables', []) # defining variables to be things under key 'variables'
            self.hyperparameters = config.get('BDT hyperparameters', {}) # defining hyperparameters to be things under 'hyperparameters' - if dne, returns empty dict "{}"

        # if error occurs inside the try, will give this formatted error
        except Exception as e:
            raise ValueError(f"Error parsing YAML file: {e}") # f-string that lets you embed variables in string

    def _load_data(self):
        for sample_type, key in [("background", 0), ("signal", 1)]: # iterating this for loop, once for signal, once for background
            sample_list = self.samples[key] # calling all the background/signal samples
            dataframes = []

            for sample in sample_list:
                files = glob.glob(os.path.join(f"{self.input_paths}/{sample}/", "*.root")) # joining the sample with input path and making root file
                for file in files: ## why do we need this for loop, if there should only be one file found for each sample?
                    self.tree = uproot.open(file)['analysis'] # opening root file and ttree
                    variables_with_b_w = self.variables + ['b_w']
                    df = self.tree.arrays(variables_with_b_w, library="pd") # turning tree into pd df
                    df['sample'] = sample # adding column for sample name
                    df['label'] = key # adding column for 0 or 1
                    dataframes.append(df) # adding all background df into one list

            combined_df = pd.concat(dataframes, ignore_index=True).dropna() # concatinating the list of df into one full df
            self.dataframes[sample_type] = combined_df # making the df an attribute, and placing them in dictionary with the key of either signal or background

    def print_config(self):
        """Prints the current configuration."""
        print(f"Input Paths: {self.input_paths}")
        print(f"Samples: {self.samples}")
        print(f"Variables: {self.variables}")
        print(f"Hyperparameters: {self.hyperparameters}")

    def prepare_data(self):
        # putting data into sep background and signal df
        self.background_df = self.dataframes["background"]
        self.signal_df = self.dataframes["signal"]

        # computing ratio between sig and back for reweighting when training model
        #self.scale = len(background_df) / len(signal_df)

        self.combined_df = pd.concat([self.background_df, self.signal_df], ignore_index=True) # combining sig and back df into one df
        # splitting df into X and y
        self.X = self.combined_df[self.variables]  # Use only the specified variables
        self.y = self.combined_df['label']
        self.weights = self.combined_df['b_w']

        # returning the train/test split so can be used later in class
        return train_test_split(self.X, self.y, self.weights, test_size=0.3, random_state=42)

    def train_model(self, model_path="xgboost_model.json", importance_plot_path=None): # function parameters with defaults (if don't pass anything when calling function)
        self.X_train, self.X_test, self.y_train, self.y_test, b_w_train, b_w_test = self.prepare_data() # defining X and y train/test

        scaling_factor = 1.0 / b_w_train.mean()
        b_w_train *= scaling_factor
        b_w_test *= scaling_factor
        print("Signal total weight:", b_w_train[self.y_train == 1].sum())
        print("Background total weight:", b_w_train[self.y_train == 0].sum())
        
        # creating DMatrix models of the train and test sets - model is the XGBoost's optimized internal format for data
        dtrain = xgb.DMatrix(data=self.X_train, label=self.y_train, weight=b_w_train, feature_names=self.X_train.columns.tolist()) # gives column names of df as a list
        dtest = xgb.DMatrix(data=self.X_test, label=self.y_test, weight=b_w_test, feature_names=self.X_test.columns.tolist())

        # defining parameters for the model
        evals_result = {}
        scale_og = self.y_train.value_counts()[0] / self.y_train.value_counts()[1]
        scale_b_w = b_w_train[self.y_train == 0].sum() / b_w_train[self.y_train == 1].sum()
        print(scale_og)
        print(scale_b_w)

        params = {
            "objective": "binary:logistic", # saying we want this model to be a binary classifier
            "eval_metric": "logloss",
            "eta": self.hyperparameters.get("learning_rate", 0.1), # saying to get learning rate from hyperp, but if not there, use 0.1
            "max_depth": self.hyperparameters.get("max_depth", 3), # saying to get depth from hyperp, but if not there, use 3
            "random_state": 42,
            "scale_pos_weight": scale_b_w
        }

        evals = [(dtrain, "train"), (dtest, "test")] # telling which datasets to evaluate during training
        # creating and training models
        self.model = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=self.hyperparameters.get("n_estimators", 100),
            evals=evals,
            evals_result=evals_result,
            early_stopping_rounds=10, # if validation set doesn't improve for 10 rounds, training will stop early to prevent overfitting
            verbose_eval=True
        )

        self.y_pred_prob = self.model.predict(dtest)
        self.y_pred_binary = [1 if prob > 0.5 else 0 for prob in self.y_pred_prob]

        # printing accuracy scores for the model
        print(f"Accuracy: {accuracy_score(self.y_test, self.y_pred_binary):.2%}") # telling to formal output as percentage
        print(f"AUC: {roc_auc_score(self.y_test, self.y_pred_prob):.2f}") # telling to format output as fixed point decimal w/2 digits after .
        print(f"F1-Score: {f1_score(self.y_test, self.y_pred_binary):.2f}")

        self.model.save_model(model_path) # saving the model to the path so it can be accessed later without having to fully rerun
        print(f"Model saved to {model_path}")

        # plotting the log loss graph
        results = evals_result
        epochs = len(results['train']['logloss'])
        x_axis = range(0, epochs)

        plt.figure(figsize=(10, 6))
        plt.plot(x_axis, results['train']['logloss'], label='Training set')
        plt.plot(x_axis, results['test']['logloss'], label='Validation set')
        plt.tick_params(axis='both', labelsize=18)
        plt.xlabel('Number of Trees', fontsize=20)
        plt.ylabel('Log Loss', fontsize=20)
        plt.title('Log Loss', fontsize=20)
        plt.legend(fontsize=15)
        plt.show()

        # plotting feature importance 
        self.plot_feature_importance(save_path=importance_plot_path) # calls later function to plot feature importance
       
        return self.model

    def find_optimal_bdt_threshold(self):
        if not hasattr(self, 'model'): # checking to make sure there is a model
            raise AttributeError("The model has not been trained. Train the model before calculating S/sqrt(B).")

        # Generate scores using the trained model
        dmatrix = xgb.DMatrix(data=self.X, feature_names=self.X.columns.tolist())
        bdt_scores = self.model.predict(dmatrix)

        # Add scores and labels to a combined DataFrame
        self.combined_df = pd.DataFrame({
            'bdt_score': bdt_scores,
            'label': self.y
        })

        # Initialize variables to track the optimal threshold
        max_significance = 0
        optimal_threshold = 0

        for threshold in np.arange(0, 1.01, 0.01):
            # calculating the amount of signal and background over the threshold and just getting the number of rows (so number of counts)
            signal_count = self.combined_df[(self.combined_df['bdt_score'] > threshold) & (self.combined_df['label'] == 1)].shape[0]
            background_count = self.combined_df[(self.combined_df['bdt_score'] > threshold) & (self.combined_df['label'] == 0)].shape[0]

            if background_count > 0:
                significance = signal_count / np.sqrt(background_count) # calculating significance of that specific threshold
            else:
                significance = 0

            # if significance is highest yet, storing that in the max_significance variable
            if significance > max_significance:
                max_significance = significance
                optimal_threshold = threshold

        print(f"Maximum S/sqrt(B) = {max_significance:.2f} at BDT score threshold = {optimal_threshold:.2f}")
        return optimal_threshold
    
    def plot_feature_importance(self, feature_names=None, save_path=None):
        # plotting feature importance
        plt.figure(figsize=(10, 6))
        xgb.plot_importance(self.model, importance_type='gain', values_format='{v:.2f}')
        plt.title("Feature Importance by Gain", fontsize=16)
        plt.tight_layout()

        # if you want to save the feature importance on something
        if save_path:
            plt.savefig(save_path)
            print(f"Feature importance plot saved to {save_path}")
    
        plt.show()
        
    def plot_bdt_score(self, save_path=None):
        if not hasattr(self, 'model'):
            raise AttributeError("The model has not been trained. Train the model before plotting BDT scores.")
    
        # Generate scores using the trained model
        dmatrix = xgb.DMatrix(data=self.X, feature_names=self.variables)
        self.bdt_scores = self.model.predict(dmatrix)
    
        # Separate background and signal
        self.combined_df['bdt_score'] = self.bdt_scores
        background_scores = self.combined_df[self.combined_df['label'] == 0]['bdt_score'] # selects rows where 'label' = 0, and then from those rows, only takes the 'BDT score' column
        signal_scores = self.combined_df[self.combined_df['label'] == 1]['bdt_score']
    
        # Normalize each group to unity
        background_weights = [1 / len(background_scores)] * len(background_scores) if len(background_scores) > 0 else []
        signal_weights = [1 / len(signal_scores)] * len(signal_scores) if len(signal_scores) > 0 else []
    
        # Plot histograms
        plt.figure(figsize=(10, 6))
        plt.hist(background_scores, bins=50, weights=background_weights, alpha=0.7, label='Background (Label 0)', color='blue')
        plt.hist(signal_scores, bins=50, weights=signal_weights, alpha=0.7, label='Signal (Label 1)', color='red')

        plt.tick_params(axis='both', labelsize=18)
        plt.xlabel("BDT Score", fontsize=20)
        plt.ylabel("Normalized Density", fontsize=20)
        plt.title("BDT Score Distribution", fontsize=20)
        plt.legend(loc='best', fontsize=15)
        plt.tight_layout()
    
        # Save the plot if a path is provided
        if save_path:
            plt.savefig(save_path)
            print(f"BDT score plot saved to {save_path}")
    
        plt.show()

    def roc_curve(self):
        test_bdt_scores = self.model.predict(xgb.DMatrix(self.X_test))
        
        fpr, tpr, thresholds = roc_curve(self.y_test, test_bdt_scores)
        plt.plot(fpr, tpr)
        plt.tick_params(axis='both', labelsize=14)
        plt.xlabel('False Positive Rate', fontsize=16)
        plt.ylabel('True Positive Rate', fontsize=16)
        plt.title("ROC Curve", fontsize=18)
        plt.show()

    def confusion_matrix(self):
        # getting binary predictions
        
        cm = metrics.confusion_matrix(self.y_test, self.y_pred_binary)
        cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [0, 1])
        cm_display.plot()
        plt.tick_params(axis='both', labelsize=14)
        plt.xlabel("Predicted label", fontsize=16)
        plt.ylabel("True label", fontsize=16)
        plt.title('Confusion Matrix', fontsize=18)
        plt.show()

    def correlation_matrix(self):
        correlation = self.X[self.variables].corr()

        sns.heatmap(correlation, annot=True, cmap='coolwarm', cbar=True, square=True, linewidths=0.5, annot_kws={'size': 6}, fmt='.1f')
        plt.tick_params(axis='both', labelsize=8)
        plt.title('Correlation Matrix', fontsize=15)
        
    def dump_samples_to_root(self, output_dir="categorized_arrays", bdt_score_threshold=0.5):
        if not hasattr(self, 'model'):
            raise AttributeError("The model has not been trained. Train the model before dumping samples.")
    
        # Generate scores using the trained model
        dmatrix = xgb.DMatrix(data=self.X, feature_names=self.variables)
        bdt_scores = self.model.predict(dmatrix)
    
        # Apply the BDT score threshold
        selected_df = self.combined_df[combined_df['bdt_score'] > bdt_score_threshold].copy() # only giving events that the BDT "scores high" and "should" be signal
    
        # Ensure the required variables exist in the DataFrame
        required_columns = ['bdt_score', 'b_mZstar_jj', 'sample']
        if not all(col in selected_df.columns for col in required_columns):
            raise KeyError(f"The following required columns are missing: {set(required_columns) - set(selected_df.columns)}")
    
        # Create output directory if it doesn't exist
        os.makedirs(output_dir, exist_ok=True)
    
        # Group by sample name and save each group to a separate ROOT file
        for sample_name, sample_df in selected_df.groupby('sample'):
            output_file = os.path.join(output_dir, f"{sample_name}.root")
    
            # Save to ROOT file
            with uproot.recreate(output_file) as root_file:
                root_file["tree"] = {
                    "bdt_score": sample_df['bdt_score'].to_numpy(dtype=np.float32),
                    "b_mZstar_jj": sample_df['b_mZstar_jj'].to_numpy(dtype=np.float32)}
            print(f"Saved ROOT file for Sample {sample_name} at: {output_file}")

    # looking at imbalance between signal and background events
    def class_imbalance(self):
        counts = self.combined_df['label'].value_counts()
        print(counts)

    # inspecting low-scoring signal events
    def low_signal(self):
        test_df = self.X_test.copy()
        test_df['Label'] = self.y_test.values
        test_df['BDT_score'] = self.y_pred_prob

        signal_events = test_df[test_df['Label'] == 1]
        low_signal = signal_events[signal_events['BDT_score'] < 0.8]

    def variable_distributions_unscale(self, variable):

        # define signal and background weights
        background_weights = self.background_df['b_w']
        signal_weights = self.signal_df['b_w']

        # make the plot
        plt.figure(figsize=(10, 6))
        plt.hist(self.background_df[variable], bins=20, weights=background_weights, edgecolor='black', alpha=0.7, label='Background')
        plt.hist(self.signal_df[variable], bins=20, weights=signal_weights, edgecolor='black', alpha=0.7, label='Signal')

        plt.tick_params(axis='both', labelsize=18)
        plt.xlabel('Reconstructed Mass of Z*', fontsize=20)
        plt.ylabel('Entries (normalized)', fontsize=20)
        plt.title('Variable Distributions Before Scaling', fontsize=20)
        plt.legend(fontsize=18)
        plt.show()

    def variable_distributions_scale(self, variable):
        
        # define signal and background weights
        background_weights = self.background_df['b_w']
        signal_weights = self.signal_df['b_w']

        # set scaling factor
        self.prepare_data()
        _, _, _, _, b_w_train, _ = train_test_split(self.X, self.y, self.weights, test_size=0.3, random_state=15)
        scaling_factor = 1.0 / b_w_train.mean()

        # set scale
        background_weights = self.background_df['b_w'] * scaling_factor
        signal_weights = self. signal_df['b_w'] * scaling_factor

        scale_b_w = background_weights.sum() / signal_weights.sum()
        signal_weights *= scale_b_w

        min_val = min(self.background_df[variable].min(), self.signal_df[variable].min())
        max_val = max(self.background_df[variable].max(), self.signal_df[variable].max())

        common_range = (min_val, max_val)

        # make the plot
        plt.figure(figsize=(10, 6))
        plt.hist(self.background_df[variable], color='blue', bins=20, range=common_range, weights=background_weights, alpha=0.7, label='Background', edgecolor='black')
        plt.hist(self.signal_df[variable], color='red', bins=20, range=common_range, weights=signal_weights, alpha=0.7, label='Signal', edgecolor='black')

        plt.tick_params(axis='both', labelsize=14)
        plt.xlabel('Reconstructed Mass of Z* (GeV)', fontsize=16)
        plt.ylabel('Entries (normalized)', fontsize=16)
        plt.title('Variable Distributions After Scaling', fontsize=18)
        plt.legend(fontsize=14)
        plt.show()

# %%
bdt = BinaryDecisionTreeSelf_df('nersc.yaml')
bdt.train_model()
bdt.plot_bdt_score()
bdt.find_optimal_bdt_threshold()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 bdt = BinaryDecisionTreeSelf_df('nersc.yaml')
#       2 bdt.train_model()
#       3 bdt.plot_bdt_score()
#
# Cell In[2], line 18, in BinaryDecisionTreeSelf_df.__init__(self, yaml_file)
#      15 # calling two of the functions up here, even though only defined below
#      16 # can do this bc reads classes all first, then goes through
#      17 self._parse_yaml(yaml_file)
# ---> 18 self._load_data()
#
# Cell In[2], line 45, in BinaryDecisionTreeSelf_df._load_data(self)
#      43 files = glob.glob(os.path.join(f"{self.input_paths}/{sample}/", "*.root")) # joining the sample with input path and making root file
#      44 for file in files: ## why do we need this for loop, if there should only be one file found for each sample?
# ---> 45     self.tree = uproot.open(file)['analysis'] # opening root file and ttree
#      46     variables_with_b_w = self.variables + ['b_w']
#      47     df = self.tree.arrays(variables_with_b_w, library="pd") # turning tree into pd df
#
# File ~/.local/perlmutter/python-3.11/lib/python3.11/site-packages/uproot/reading.py:142, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     133 if not isinstance(file_path, str) and not (
#     134     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     135 ):
#     136     raise ValueError(
#     137         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     138         "'seek' methods, or a length-1 dict of {file_path: object_path}, "
#     139         f"not {path!r}"
#     140     )
# --> 142 file = ReadOnlyFile(
#     143     file_path,
#     144     object_cache=object_cache,
#     145     array_cache=array_cache,
#     146     custom_classes=custom_classes,
#     147     decompression_executor=decompression_executor,
#     148     interpretation_executor=interpretation_executor,
#     149     **options,
#     150 )
#     152 if object_path is None:
#     153     return file.root_directory
#
# File ~/.local/perlmutter/python-3.11/lib/python3.11/site-packages/uproot/reading.py:573, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     565 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#     566     raise ValueError(
#     567         "begin_chunk_size={} is not enough to read the TFile header ({})".format(
#     568             self._options["begin_chunk_size"],
#     569             _file_header_fields_big.size,
#     570         )
#     571     )
# --> 573 self._begin_chunk = self._source.chunk(
#     574     0, self._options["begin_chunk_size"]
#     575 ).detach_memmap()
#     577 self.hook_before_interpret()
#     579 (
#     580     magic,
#     581     self._fVersion,
#    (...)
#     595     self._begin_chunk, _file_header_fields_small, {}
#     596 )
#
# File ~/.local/perlmutter/python-3.11/lib/python3.11/site-packages/uproot/source/fsspec.py:95, in FSSpecSource.chunk(self, start, stop)
#      93 self._num_requested_chunks += 1
#      94 self._num_requested_bytes += stop - start
# ---> 95 data = self._fs.cat_file(self._file_path, start=start, end=stop)
#      96 future = uproot.source.futures.TrivialFuture(data)
#      97 return uproot.source.chunk.Chunk(self, start, stop, future)
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/fsspec/spec.py:766, in AbstractFileSystem.cat_file(self, path, start, end, **kwargs)
#     754 """Get the content of a file
#     755
#     756 Parameters
#    (...)
#     763 kwargs: passed to ``open()``.
#     764 """
#     765 # explicitly set buffering off?
# --> 766 with self.open(path, "rb", **kwargs) as f:
#     767     if start is not None:
#     768         if start >= 0:
#
# File /global/common/software/nersc/pe/conda-envs/24.1.0/python-3.11/nersc-python/lib/python3.11/site-packages/fsspec/spec.py:1295, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1293 else:
#    1294     ac = kwargs.pop("autocommit", not self._intrans)
# -> 
# [659]	train-logloss:0.08328	test-logloss:0.12730
# [660]	train-logloss:0.08317	test-logloss:0.12719
# [661]	train-logloss:0.08307	test-logloss:0.12709
# [662]	train-logloss:0.08297	test-logloss:0.12699
# [663]	train-logloss:0.08279	test-logloss:0.12680
# [664]	train-logloss:0.08270	test-logloss:0.12671
# [665]	train-logloss:0.08260	test-logloss:0.12660
# [666]	train-logloss:0.08246	test-logloss:0.12645
# [667]	train-logloss:0.08242	test-logloss:0.12641
# [668]	train-logloss:0.08233	test-logloss:0.12631
# [669]	train-logloss:0.08224	test-logloss:0.12622
# [670]	train-logloss:0.08220	test-logloss:0.12618
# [671]	train-logloss:0.08210	test-logloss:0.12606
# [672]	train-logloss:0.08206	test-logloss:0.12603
# [673]	train-logloss:0.08197	test-logloss:0.12592
# [674]	train-logloss:0.08194	test-logloss:0.12589
# [675]	train-logloss:0.08185	test-logloss:0.12579
# [676]	train-logloss:0.08175	test-logloss:0.12569
# [677]	train-logloss:0.08168	test-logloss:0.12562
# [678]	train-logloss:0.08150	test-logloss:0.12543
# [679]	train-logloss:0.08147	test-logloss:0.12539
# [680]	train-logloss:0.08138	test-logloss:0.12530
# [681]	train-logloss:0.08130	test-logloss:0.12521
# [682]	train-logloss:0.08126	test-logloss:0.12517
# [683]	train-logloss:0.08116	test-logloss:0.12507
# [684]	train-logloss:0.08108	test-logloss:0.12498
# [685]	train-logloss:0.08098	test-logloss:0.12488
# [686]	train-logloss:0.08089	test-logloss:0.12479
# [687]	train-logloss:0.08086	test-logloss:0.12474
# [688]	train-logloss:0.08077	test-logloss:0.12465
# [689]	train-logloss:0.08064	test-logloss:0.12451
# [690]	train-logloss:0.08061	test-logloss:0.12448
# [691]	train-logloss:0.08052	test-logloss:0.12439
# [692]	train-logloss:0.08049	test-logloss:0.12435
# [693]	train-logloss:0.08038	test-logloss:0.12424
# [694]	train-logloss:0.08029	test-logloss:0.12414
# [695]	train-logloss:0.08020	test-logloss:0.12405
# [696]	train-logloss:0.08012	test-logloss:0.12396
# [697]	train-logloss:0.07999	test-logloss:0.12382
# [698]	train-logloss:0.07996	test-logloss:0.12379
# [699]	train-logloss:0.07988	test-logloss:0.12370
# Accuracy: 88.22%
# AUC: 0.83
# F1-Score: 0.22
# Model saved to xgboost_model.json

# %%
bdt = BinaryDecisionTreeSelf_df('nersc.yaml')
bdt.prepare_data()
bdt.variable_distributions_scale('b_Zstar_j1FlavorIdx')

# %%
class Test:
    def __init__(self, yaml_file: str): # identifying that the yaml file should be a string
        """
        Initialize with configurations from a YAML file.
        :param yaml_file: Path to the YAML configuration file.
        """
        # defining each of the attributes
        self.input_paths = None
        self.samples = {}
        self.variables = []
        self.hyperparameters = {}
        self.model = None
        self.dataframes = {"background": None, "signal": None}

        # calling two of the functions up here, even though only defined below
        # can do this bc reads classes all first, then goes through
        self._parse_yaml(yaml_file)
        self._load_data()

    def _parse_yaml(self, yaml_file: str):
        try: # try means that if error happens, it'll go to exception
            # use 'with' to make sure that yaml file is closed after it's opened
            with open(yaml_file, 'r' ) as file: # telling to read the file and call it "file"
                config = yaml.safe_load(file)

            # defining the attributes from things inside yaml file
            self.input_paths = config['input_path']
            self.samples[0] = config.get(0, []) # defining first column of samples as those under the key 0 in the yaml file - also, if 0 doesn't exist, return empty list "[]"
            self.samples[1] = config.get(1, []) # defining second column of samples to be things under key 1 in file
            self.variables = config.get('variables', []) # defining variables to be things under key 'variables'
            self.hyperparameters = config.get('BDT hyperparameters', {}) # defining hyperparameters to be things under 'hyperparameters' - if dne, returns empty dict "{}"

        # if error occurs inside the try, will give this formatted error
        except Exception as e:
            raise ValueError(f"Error parsing YAML file: {e}") # f-string that lets you embed variables in string

    def _load_data(self):
        for sample_type, key in [("background", 0), ("signal", 1)]: # iterating this for loop, once for signal, once for background
            sample_list = self.samples[key] # calling all the background/signal samples
            dataframes = []

            for sample in sample_list:
                files = glob.glob(os.path.join(f"{self.input_paths}/{sample}/", "*.root")) # joining the sample with input path and making root file
                for file in files: ## why do we need this for loop, if there should only be one file found for each sample?
                    self.tree = uproot.open(file)['analysis'] # opening root file and ttree
                    variables_with_b_w = self.variables + ['b_w']
                    df = self.tree.arrays(variables_with_b_w, library="pd") # turning tree into pd df
                    df['sample'] = sample # adding column for sample name
                    df['label'] = key # adding column for 0 or 1
                    dataframes.append(df) # adding all background df into one list

            combined_df = pd.concat(dataframes, ignore_index=True).dropna() # concatinating the list of df into one full df
            self.dataframes[sample_type] = combined_df # making the df an attribute, and placing them in dictionary with the key of either signal or background

    def print_config(self):
        """Prints the current configuration."""
        print(f"Input Paths: {self.input_paths}")
        print(f"Samples: {self.samples}")
        print(f"Variables: {self.variables}")
        print(f"Hyperparameters: {self.hyperparameters}")

    def prepare_data(self):
        # putting data into sep background and signal df
        self.background_df = self.dataframes["background"]
        self.signal_df = self.dataframes["signal"]

        # computing ratio between sig and back for reweighting when training model
        #self.scale = len(background_df) / len(signal_df)

        self.combined_df = pd.concat([self.background_df, self.signal_df], ignore_index=True) # combining sig and back df into one df
        # splitting df into X and y
        self.X = self.combined_df[self.variables]  # Use only the specified variables
        self.y = self.combined_df['label']
        self.weights = self.combined_df['b_w']

        # returning the train/test split so can be used later in class
        return train_test_split(self.X, self.y, self.weights, test_size=0.3, random_state=42)

    def train_model(self, model_path="xgboost_model.json", importance_plot_path=None): # function parameters with defaults (if don't pass anything when calling function)
        self.X_train, self.X_test, self.y_train, self.y_test, b_w_train, b_w_test = self.prepare_data() # defining X and y train/test

        scaling_factor = 1.0 / b_w_train.mean()
        b_w_train *= scaling_factor
        b_w_test *= scaling_factor
        print("Signal total weight:", b_w_train[self.y_train == 1].sum())
        print("Background total weight:", b_w_train[self.y_train == 0].sum())
        
        # creating DMatrix models of the train and test sets - model is the XGBoost's optimized internal format for data
        dtrain = xgb.DMatrix(data=self.X_train, label=self.y_train, weight=b_w_train, feature_names=self.X_train.columns.tolist()) # gives column names of df as a list
        dtest = xgb.DMatrix(data=self.X_test, label=self.y_test, weight=b_w_test, feature_names=self.X_test.columns.tolist())

        # defining parameters for the model
        evals_result = {}
        scale_og = self.y_train.value_counts()[0] / self.y_train.value_counts()[1]
        scale_b_w = b_w_train[self.y_train == 0].sum() / b_w_train[self.y_train == 1].sum()
        print(scale_og)
        print(scale_b_w)

        params = {
            "objective": "binary:logistic", # saying we want this model to be a binary classifier
            "eval_metric": "logloss",
            "eta": self.hyperparameters.get("learning_rate", 0.1), # saying to get learning rate from hyperp, but if not there, use 0.1
            "max_depth": self.hyperparameters.get("max_depth", 3), # saying to get depth from hyperp, but if not there, use 3
            "random_state": 42,
            "scale_pos_weight": scale_b_w
        }

        evals = [(dtrain, "train"), (dtest, "test")] # telling which datasets to evaluate during training
        # creating and training models
        self.model = xgb.train(
            params=params,
            dtrain=dtrain,
            num_boost_round=self.hyperparameters.get("n_estimators", 100),
            evals=evals,
            evals_result=evals_result,
            early_stopping_rounds=10, # if validation set doesn't improve for 10 rounds, training will stop early to prevent overfitting
            verbose_eval=True
        )

        self.y_pred_prob = self.model.predict(dtest)
        self.y_pred_binary = [1 if prob > 0.5 else 0 for prob in self.y_pred_prob]

        # printing accuracy scores for the model
        print(f"Accuracy: {accuracy_score(self.y_test, self.y_pred_binary):.2%}") # telling to formal output as percentage
        print(f"AUC: {roc_auc_score(self.y_test, self.y_pred_prob):.2f}") # telling to format output as fixed point decimal w/2 digits after .
        print(f"F1-Score: {f1_score(self.y_test, self.y_pred_binary):.2f}")

        self.model.save_model(model_path) # saving the model to the path so it can be accessed later without having to fully rerun
        print(f"Model saved to {model_path}")

        # plotting the log loss graph
        results = evals_result
        epochs = len(results['train']['logloss'])
        x_axis = range(0, epochs)

        plt.figure(figsize=(10, 6))
        plt.plot(x_axis, results['train']['logloss'], label='Training set')
        plt.plot(x_axis, results['test']['logloss'], label='Validation set')
        plt.tick_params(axis='both', labelsize=18)
        plt.xlabel('n_estimators', fontsize=20)
        plt.ylabel('Log Loss', fontsize=20)
        plt.title('Log Loss', fontsize=20)
        plt.legend()
        plt.show()

        return self.model

    def calc_scores(self):
        # Generate scores using the trained model
        dmatrix = xgb.DMatrix(data=self.X, feature_names=self.variables)
        self.bdt_scores = self.model.predict(dmatrix)
    
        # Separate background and signal
        self.combined_df['bdt_score'] = self.bdt_scores
        background_scores = self.combined_df[self.combined_df['label'] == 0]['bdt_score'] # selects rows where 'label' = 0, and then from those rows, only takes the 'BDT score' column
        signal_scores = self.combined_df[self.combined_df['label'] == 1]['bdt_score']
    
        # Normalize each group to unity
        background_weights = [1 / len(background_scores)] * len(background_scores) if len(background_scores) > 0 else []
        signal_weights = [1 / len(signal_scores)] * len(signal_scores) if len(signal_scores) > 0 else []

    def confusion_matrix(self):
        # getting binary predictions
        
        cm = metrics.confusion_matrix(self.y_test, self.y_pred_binary)
        cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [0, 1])
        cm_display.plot()
        plt.tick_params(axis='both', labelsize=18)
        plt.title('Confusion Matrix', fontsize=20)
        plt.show()

    def correlation_matrix(self):
        correlation = self.X[self.variables].corr()

        sns.heatmap(correlation, annot=True, cmap='coolwarm', cbar=True, square=True, linewidths=0.5, annot_kws={'size': 6}, fmt='.1f')
        plt.tick_params(axis='both', labelsize=8)
        plt.title('Correlation Matrix', fontsize=15)

# %%
testbdt = Test('test.yaml')
testbdt.train_model()
testbdt.calc_scores()
# Out:
# Signal total weight: 31482.131118840858
# Background total weight: 1823819.8688811592
# 2.158122116874053
# 57.93190626125283
# [0]	train-logloss:0.68675	test-logloss:0.68665
# [1]	train-logloss:0.68096	test-logloss:0.68075
# [2]	train-logloss:0.67575	test-logloss:0.67544
# [3]	train-logloss:0.67091	test-logloss:0.67052
# [4]	train-logloss:0.66643	test-logloss:0.66596
# [5]	train-logloss:0.66238	test-logloss:0.66185
# [6]	train-logloss:0.65811	test-logloss:0.65752
# [7]	train-logloss:0.65401	test-logloss:0.65337
# [8]	train-logloss:0.65017	test-logloss:0.64945
# [9]	train-logloss:0.64711	test-logloss:0.64634
# [10]	train-logloss:0.64371	test-logloss:0.64289
# [11]	train-logloss:0.64065	test-logloss:0.63982
# [12]	train-logloss:0.63818	test-logloss:0.63732
# [13]	train-logloss:0.63531	test-logloss:0.63441
# [14]	train-logloss:0.63275	test-logloss:0.63184
# [15]	train-logloss:0.63030	test-logloss:0.62936
# [16]	train-logloss:0.62809	test-logloss:0.62709
# [17]	train-logloss:0.62616	test-logloss:0.62513
# [18]	train-logloss:0.62419	test-logloss:0.62320
# [19]	train-logloss:0.62195	test-logloss:0.62097
# [20]	train-logloss:0.62031	test-logloss:0.61933
# [21]	train-logloss:0.61865	test-logloss:0.61768
# [22]	train-logloss:0.61692	test-logloss:0.61597
# [23]	train-logloss:0.61559	test-logloss:0.61461
# [24]	train-logloss:0.61407	test-logloss:0.61315
# [25]	train-logloss:0.61246	test-logloss:0.61153
# [26]	train-logloss:0.61125	test-logloss:0.61037
# [27]	train-logloss:0.61017	test-logloss:0.60932
# [28]	train-logloss:0.60871	test-logloss:0.60788
# [29]	train-logloss:0.60751	test-logloss:0.60670
# [30]	train-logloss:0.60652	test-logloss:0.60574
# [31]	train-logloss:0.60510	test-logloss:0.60431
# [32]	train-logloss:0.60409	test-logloss:0.60334
# [33]	train-logloss:0.60301	test-logloss:0.60228
# [34]	train-logloss:0.60196	test-logloss:0.60127
# [35]	train-logloss:0.60109	test-logloss:0.60040
# [36]	train-logloss:0.60015	test-logloss:0.59949
# [37]	train-logloss:0.59925	test-logloss:0.59862
# [38]	train-logloss:0.59837	test-logloss:0.59778
# [39]	train-logloss:0.59759	test-logloss:0.59701
# [40]	train-logloss:0.59679	test-logloss:0.59622
# [41]	train-logloss:0.59597	test-logloss:0.59543
# [42]	train-logloss:0.59525	test-logloss:0.59475
# [43]	train-logloss:0.59448	test-logloss:0.59397
# [44]	train-logloss:0.59374	test-logloss:0.59330
# [45]	train-logloss:0.59298	test-logloss:0.59257
# [46]	train-logloss:0.59228	test-logloss:0.59188
